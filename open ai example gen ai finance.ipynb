# %%
# !pip install openai
# !pip install --upgrade openai
# !pip install openai==0.28
# Out:
# Requirement already satisfied: openai in ./anaconda3/lib/python3.12/site-packages (0.28.0)
# Collecting openai
#   Using cached openai-1.55.3-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./anaconda3/lib/python3.12/site-packages (from openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./anaconda3/lib/python3.12/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./anaconda3/lib/python3.12/site-packages (from openai) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./anaconda3/lib/python3.12/site-packages (from openai) (0.8.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in ./anaconda3/lib/python3.12/site-packages (from openai) (2.8.2)
# Requirement already satisfied: sniffio in ./anaconda3/lib/python3.12/site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in ./anaconda3/lib/python3.12/site-packages (from openai) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in ./anaconda3/lib/python3.12/site-packages (from openai) (4.11.0)
# Requirement already satisfied: idna>=2.8 in ./anaconda3/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: certifi in ./anaconda3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in ./anaconda3/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in ./anaconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in ./anaconda3/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in ./anaconda3/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (2.20.1)
# Using cached openai-1.55.3-py3-none-any.whl (389 kB)
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 0.28.0
#     Uninstalling openai-0.28.0:
#       Successfully uninstalled openai-0.28.0
# Successfully installed openai-1.55.3

# %% [raw]
# import openai
#
# # Set your OpenAI API key (replace 'your-api-key' with your actual key)
# openai.api_key = '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'
#
# # Function to query OpenAI's GPT model for a financial question or task
# def generate_financial_analysis(prompt):
#     try:
#         # Call OpenAI's API to generate a response based on the input prompt
#         response = openai.Completion.create(
#             engine="text-davinci-003",  # Use the most advanced model
#             prompt=prompt,  # The prompt you want to send to the model
#             temperature=0.7,  # Controls creativity; lower values make it more deterministic
#             max_tokens=150,  # Maximum length of the response
#             top_p=1,  # Control diversity via nucleus sampling
#             frequency_penalty=0,  # Prevent the model from repeating itself
#             presence_penalty=0  # Prevent the model from being too generic
#         )
#
#         # Return the generated response
#         return response.choices[0].text.strip()
#
#     except Exception as e:
#         return f"Error: {e}"
#
# # Example prompts for financial analysis
# prompts = [
#     "Analyze the impact of rising interest rates on stock markets and bond prices.",
#     "What are the key factors that influence the price of Bitcoin?",
#     "Explain the concept of risk management in portfolio diversification.",
#     "What is the economic outlook for the US economy in 2024?"
# ]
#
# # Generate financial insights for each prompt
# for prompt in prompts:
#     print(f"Prompt: {prompt}\n")
#     print("Generated Response:\n")
#     print(generate_financial_analysis(prompt))
#     print("\n" + "="*50 + "\n")

# %% [raw]
# import openai
#
# # Set your OpenAI API key (replace 'your-api-key' with your actual key)
# openai.api_key = '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'
# # Function to query OpenAI's GPT model for finance-related content
# def generate_financial_analysis(prompt):
#     try:
#         # Using the correct API for the new version (1.0+)
#         response = openai.Completion.create(
#             model="text-davinci-003",  # Or "gpt-3.5-turbo" if you want to use GPT-3.5
#             prompt=prompt,
#             temperature=0.7,  # Adjust creativity
#             max_tokens=150,  # Control response length
#             n=1,  # Number of completions to generate
#             stop=None,  # Specify stop tokens if needed
#         )
#
#         # Return the generated response
#         return response.choices[0].text.strip()
#
#     except Exception as e:
#         return f"Error: {e}"
#
# # Example prompts for financial analysis
# prompts = [
#     "Analyze the impact of rising interest rates on stock markets and bond prices.",
#     "What are the key factors that influence the price of Bitcoin?",
#     "Explain the concept of risk management in portfolio diversification.",
#     "What is the economic outlook for the US economy in 2024?"
# ]
#
# # Generate financial insights for each prompt
# for prompt in prompts:
#     print(f"Prompt: {prompt}\n")
#     print("Generated Response:\n")
#     print(generate_financial_analysis(prompt))
#     print("\n" + "="*50 + "\n")

# %% [raw]
# import openai
#
# # Set your OpenAI API key (replace 'your-api-key' with your actual key)
# openai.api_key = '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'
#
# # Function to query OpenAI's GPT model for finance-related content
# def generate_financial_analysis(prompt):
#     try:
#         # Using the correct API for the new version (1.0+)
#         response = openai.ChatCompletion.create(
#             model="gpt-4",  # You can also use "gpt-3.5-turbo" for cheaper models
#             messages=[
#                 {"role": "system", "content": "You are a helpful assistant for finance-related topics."},
#                 {"role": "user", "content": prompt}
#             ],
#             temperature=0.7,  # Adjust creativity
#             max_tokens=150,  # Control response length
#         )
#
#         # Return the generated response
#         return response['choices'][0]['message']['content'].strip()
#
#     except Exception as e:
#         return f"Error: {e}"
#
# # Example prompts for financial analysis
# prompts = [
#     "Analyze the impact of rising interest rates on stock markets and bond prices.",
#     "What are the key factors that influence the price of Bitcoin?",
#     "Explain the concept of risk management in portfolio diversification.",
#     "What is the economic outlook for the US economy in 2024?"
# ]
#
# # Generate financial insights for each prompt
# for prompt in prompts:
#     print(f"Prompt: {prompt}\n")
#     print("Generated Response:\n")
#     print(generate_financial_analysis(prompt))
#     print("\n" + "="*50 + "\n")

# %%
import openai

# Set your OpenAI API key (replace 'your-api-key' with your actual key)
openai.api_key = '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'

# Function to query OpenAI's GPT model for finance-related content
def generate_financial_analysis(prompt):
    try:
        # Use gpt-3.5-turbo as an alternative model
        response = openai.completions.create(
            model="gpt-3.5-turbo",  # Use "gpt-3.5-turbo" for accessible models
            prompt=prompt,  # Provide your prompt here
            max_tokens=150,  # Control response length
            temperature=0.7,  # Adjust creativity
        )

        # Return the generated response
        return response['choices'][0]['text'].strip()

    except Exception as e:
        return f"Error: {e}"

# Example prompts for financial analysis
prompts = [
    "Analyze the impact of rising interest rates on stock markets and bond prices.",
    "What are the key factors that influence the price of Bitcoin?",
    "Explain the concept of risk management in portfolio diversification.",
    "What is the economic outlook for the US economy in 2024?"
]

# Generate financial insights for each prompt
for prompt in prompts:
    print(f"Prompt: {prompt}\n")
    print("Generated Response:\n")
    print(generate_financial_analysis(prompt))
    print("\n" + "="*50 + "\n")
# Out:
# Prompt: Analyze the impact of rising interest rates on stock markets and bond prices.
#
# Generated Response:
#
# Error: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#
# ==================================================
#
# Prompt: What are the key factors that influence the price of Bitcoin?
#
# Generated Response:
#
# Error: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#
# ==================================================
#
# Prompt: Explain the concept of risk management in portfolio diversification.
#
# Generated Response:
#
# Error: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#
# ==================================================
#
# Prompt: What is the economic outlook for the US economy in 2024?
#
# Generated Response:
#
# Error: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#
# ==================================================
